# %% [markdown]
# # Variables

# %%
ga_input = '/grid/home/nbourgeois/data/test_proteins/hidua/hidua.pep.fas' #sequence pep.fas Input
tissue = 'Brain_Cerebellum' # Tissue type for CoCoPuts
filename = 'test'

# %% [markdown]
# # Imports

# %% [markdown]
# ## PyGAD

# %%
import os
cwd = os.getcwd()
pygad_loc = '/grid/home/nbourgeois/wip/codon_optimization'
os.chdir(pygad_loc)
import pygad
import numpy
import os
import sys
import Bio
import pandas as pd
from general_functions import *
from metrics import *
import hashlib
import subprocess
import time
os.chdir(cwd)
import importlib
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Start

# %% [markdown]
# ## Parameters

# %% [markdown]
# ### Metrics

# %%
cai_on = True
bai_on = True
sps_on = False
cpg_on = True
pas_on = False

# %% [markdown]
# ### Weights

# %%
cai_w = 1 *cai_on
bai_w = 1 *bai_on
sps_w = 1 *sps_on
cpg_w = 1 *cpg_on
pas_w = 1 *pas_on

# %%
global total_weight
total_weight = sum([cai_w,bai_w,sps_w,cpg_w,pas_w])

# %% [markdown]
# ### Locations

# %%
cai_index_loc = os.path.join(pygad_loc,'CoCoPUTs_codon_usage/codon_usage/'+tissue+'.codon.txt')
bai_index_loc = os.path.join(pygad_loc,'CoCoPUTs_codon_usage/bicodon_usage/'+tissue+'.bicodon.txt')

codon_usage_table_loc = os.path.join(pygad_loc,'references','codon_usage.getex.txt')
cai_weight_dict = get_codon_weights(cai_index_loc)
bai_weight_dict = get_bicodon_weights(bai_index_loc)

# %% [markdown]
# # Algorithm

# %% [markdown]
# ### Read in File

# %%
(keys, seqs) = readFasta(ga_input)
if len(seqs) == 1:
    aa_seq=str(seqs[0])

# %% [markdown]
# ### Initialize Parameters
# - gene_space
# - codon_to_int dictionary

# %%
global codon_to_int

codon_to_int, gene_space = init_parameters(codon_usage_table_loc, aa_seq)
    
gene_space_int = [[codon_to_int[x] for x in y] for y in gene_space]

# %% [markdown]
# # Fitness Function

# %%
def fitness_func(solution, solution_idx):
    
    if not type(solution) is str:
        seq_aa = ''.join([codon_to_int[x] for x in solution])
    else:
        seq_aa = solution
#     print(solution_idx)

    tmp_dict = {}
    
    #Check for redundancy
    if seq_aa in all_sols.keys():
        fitness = all_sols[seq_aa]['fitness']

    else:
        fitness = 0
        
        if cai_on:
            cai = get_cai(seq_aa, cai_weight_dict)
            fitness += cai*cai_w
            tmp_dict['cai'] = cai
        
        if bai_on:
            bai = get_bai(seq_aa, bai_weight_dict)
            fitness += bai*bai_w
            tmp_dict['bai'] = bai
            
        if cpg_on:
            cpg = get_cpg(seq_aa)
            fitness += cpg*cpg_w
            tmp_dict['cpg'] = cpg

        if sps_on:
            sps = get_sps(seq_aa)
            print('SPS retuned.')

            fitness += sps*sps_w
            tmp_dict['sps'] = sps

        if pas_on:
            pas = get_pas(seq_aa)
            fitness += pas*pas_w
            tmp_dict['pas'] = pas

        fitness = fitness/total_weight
        tmp_dict['fitness'] = fitness
        all_sols[seq_aa] = tmp_dict
        
    
    return fitness

# %% [markdown]
# # Genetic Algorithm

# %%
"""
Given the following function:
    y = f(w1:w6) = w1x1 + w2x2 + w3x3 + w4x4 + w5x5 + 6wx6
    where (x1,x2,x3,x4,x5,x6)=(4,-2,3.5,5,-11,-4.7) and y=44
What are the best values for the 6 weights (w1 to w6)? We are going to use the genetic algorithm to optimize this function.
"""

# def convert_aa_int():
    
desired_output = 1 # Function output.
all_sols = {}

fitness_function = fitness_func

num_generations = 1000 # Number of generations.
num_parents_mating = 5 # Number of solutions to be selected as parents in the mating pool.

sol_per_pop = 20 

parent_selection_type = "sss" # Type of parent selection.
keep_parents = 5 # Number of parents to keep in the next population. -1 means keep all parents and 0 means keep nothing.

crossover_type = "two_points" # Type of the crossover operator.

# Parameters of the mutation operation.
mutation_type = "random" # Type of the mutation operator.
mutation_percent_genes = 5 # Percentage of genes to mutate. This parameter has no action if the parameter mutation_num_genes exists or when mutation_type is None.

last_fitness = 0

def callback_generation(ga_instance):
    global last_fitness
    print("Generation = {generation}".format(generation=ga_instance.generations_completed))
    print("Fitness    = {fitness}".format(fitness=ga_instance.best_solution()[1]))
    print("Change     = {change}".format(change=ga_instance.best_solution()[1] - last_fitness))
    last_fitness = ga_instance.best_solution()[1]

# Creating an instance of the GA class inside the ga module. Some parameters are initialized within the constructor.

num_genes = len(gene_space)
ga_instance = pygad.GA(num_generations=num_generations,
                       num_parents_mating=num_parents_mating, 
                       fitness_func=fitness_function,
                       sol_per_pop=sol_per_pop, 
                       num_genes=num_genes,
                       parent_selection_type=parent_selection_type,
                       keep_parents=keep_parents,
                       crossover_type=crossover_type,
                       mutation_type=mutation_type,
                       mutation_percent_genes=mutation_percent_genes,
                       on_generation=callback_generation,
                       gene_type=int,
                       gene_space=gene_space_int,
)

# %%
# %%time

# Running the GA to optimize the parameters of the function.
ga_instance.run()

# After the generations complete, some plots are showed that summarize the how the outputs/fitenss values evolve over generations.
# ga_instance.plot_result()

# Returning the details of the best solution.
# solution, solution_fitness, solution_idx = ga_instance.best_solution()
# print("Parameters of the best solution : {solution}".format(solution=solution))
# seq_aa = ''.join([codon_to_int[x] for x in solution])
# print("NT Sequence of the best solution : {seq_aa}".format(seq_aa=seq_aa))
# print("Fitness value of the best solution = {solution_fitness}".format(solution_fitness=solution_fitness))
# print("Index of the best solution : {solution_idx}".format(solution_idx=solution_idx))

# # # prediction = numpy.sum(numpy.array(function_inputs)*solution) Replace
# # print("Predicted output based on the best solution : {prediction}".format(prediction=prediction))

# if ga_instance.best_solution_generation != -1:
#     print("Best fitness value reached after {best_solution_generation} generations.".format(best_solution_generation=ga_instance.best_solution_generation))

# Saving the GA instance.
 # The filename to which the instance is saved. The name is without extension.
# ga_instance.save(filename=filename)

# # Loading the saved GA instance.
# loaded_ga_instance = pygad.load(filename=filename)
# loaded_ga_instance.plot_result()
# Out:
# Generation = 1
# Fitness    = 0.5904401888360155
# Change     = 0.5904401888360155
# Generation = 2
# Fitness    = 0.593370091896865
# Change     = 0.0029299030608495036
# Generation = 3
# Fitness    = 0.5976500558274983
# Change     = 0.004279963930633346
# Generation = 4
# Fitness    = 0.6012940531287914
# Change     = 0.003643997301293056
# Generation = 5
# Fitness    = 0.6034356800130655
# Change     = 0.002141626884274106
# Generation = 6
# Fitness    = 0.6069126191855252
# Change     = 0.0034769391724597254
# Generation = 7
# Fitness    = 0.6098085785322079
# Change     = 0.0028959593466827416
# Generation = 8
# Fitness    = 0.6110585875175357
# Change     = 0.0012500089853277885
# Generation = 9
# Fitness    = 0.6134586448049447
# Change     = 0.0024000572874089965
# Generation = 10
# Fitness    = 0.6134586448049447
# Change     = 0.0
# Generation = 11
# Fitness    = 0.6143157042465411
# Change     = 0.0008570594415964194
# Generation = 12
# Fitness    = 0.6169801079150926
# Change     = 0.002664403668551474
# Generation = 13
# Fitness    = 0.621856064086847
# Change     = 0.004875956171754403
# Generation = 14
# Fitness    = 0.621856064086847
# Change     = 0.0
# Generation = 15
# Fitness    = 0.6219738443270395
# Change     = 0.00011778024019248878
# Generation = 16
# Fitness    = 0.6261404644876696
# Change     = 0.0041666201606300746
# Generation = 17
# Fitness    = 0.6291495535860778
# Change     = 0.0030090890984082463
# Generation = 18
# Fitness    = 0.6291495535860778
# Change     = 0.0
# Generation = 19
# Fitness    = 0.6322385704338759
# Change     = 0.003089016847798054
# Generation = 20
# Fitness    = 0.6361465184283475
# Change     = 0.003907947994471583
# Generation = 21
# Fitness    = 0.638179587608065
# Change     = 0.0020330691797175726
# Generation = 22
# Fitness    = 0.6430769217912794
# Change     = 0.0048973341832143635
# Generation = 23
# Fitness    = 0.6430769217912794
# Change     = 0.0
# Generation = 24
# Fitness    = 0.6430769217912794
# Change     = 0.0
# Generation = 25
# Fitness    = 0.6430769217912794
# Change     = 0.0
# Generation = 26
# Fitness    = 0.6430769217912794
# Change     = 0.0
# Generation = 27
# Fitness    = 0.6430769217912794
# Change     = 0.0
# Generation = 28
# Fitness    = 0.6430769217912794
# Change     = 0.0
# Generation = 29
# Fitness    = 0.643413281735933
# Change     = 0.0003363599446536414
# Generation = 30
# Fitness    = 0.643413281735933
# Change     = 0.0
# Generation = 31
# Fitness    = 0.643413281735933
# Change     = 0.0
# Generation = 32
# Fitness    = 0.643413281735933
# Change     = 0.0
# Generation = 33
# Fitness    = 0.6440835442274029
# Change     = 0.0006702624914698418
# Generation = 34
# Fitness    = 0.644711941673085
# Change     = 0.0006283974456821051
# Generation = 35
# Fitness    = 0.644711941673085
# Change     = 0.0
# Generation = 36
# Fitness    = 0.644711941673085
# Change     = 0.0
# Generation = 37
# Fitness    = 0.6482094023052932
# Change     = 0.003497460632208238
# Generation = 38
# Fitness    = 0.6482094023052932
# Change     = 0.0
# Generation = 39
# Fitness    = 0.6520856049333579
# Change     = 0.003876202628064651
# Generation = 40
# Fitness    = 0.6520856049333579
# Change     = 0.0
# Generation = 41
# Fitness    = 0.6520856049333579
# Change     = 0.0
# Generation = 42
# Fitness    = 0.6520856049333579
# Change     = 0.0
# Generation = 43
# Fitness    = 0.6520856049333579
# Change     = 0.0
# Generation = 44
# Fitness    = 0.6561349663023597
# Change     = 0.004049361369001803
# Generation = 45
# Fitness    = 0.6561349663023597
# Change     = 0.0
# Generation = 46
# Fitness    = 0.6561349663023597
# Change     = 0.0
# Generation = 47
# Fitness    = 0.6561349663023597
# Change     = 0.0
# Generation = 48
# Fitness    = 0.6575700504728611
# Change     = 0.0014350841705014217
# Generation = 49
# Fitness    = 0.6580399669012024
# Change     = 0.000469916428341266
# Generation = 50
# Fitness    = 0.6580399669012024
# Change     = 0.0
# Generation = 51
# Fitness    = 0.6580399669012024
# Change     = 0.0
# Generation = 52
# Fitness    = 0.6592095716569378
# Change     = 0.001169604755735465
# Generation = 53
# Fitness    = 0.6592095716569378
# Change     = 0.0
# Generation = 54
# Fitness    = 0.6592095716569378
# Change     = 0.0
# Generation = 55
# Fitness    = 0.6592095716569378
# Change     = 0.0
# Generation = 56
# Fitness    = 0.6592095716569378
# Change     = 0.0
# Generation = 57
# Fitness    = 0.6592095716569378
# Change     = 0.0
# Generation = 58
# Fitness    = 0.6640057948428209
# Change     = 0.0047962231858830195
# Generation = 59
# Fitness    = 0.6652678074648423
# Change     = 0.0012620126220214134
# Generation = 60
# Fitness    = 0.6652678074648423
# Change     = 0.0
# Generation = 61
# Fitness    = 0.6652678074648423
# Change     = 0.0
# Generation = 62
# Fitness    = 0.6653626329470351
# Change     = 9.48254821928618e-05
# Generation = 63
# Fitness    = 0.6653626329470351
# Change     = 0.0
# Generation = 64
# Fitness    = 0.6660745872894994
# Change     = 0.0007119543424642938
# Generation = 65
# Fitness    = 0.6660745872894994
# Change     = 0.0
# Generation = 66
# Fitness    = 0.6660745872894994
# Change     = 0.0
# Generation = 67
# Fitness    = 0.6660745872894994
# Change     = 0.0
# Generation = 68
# Fitness    = 0.6660745872894994
# Change     = 0.0
# Generation = 69
# Fitness    = 0.6660745872894994
# Change     = 0.0
# Generation = 70
# Fitness    = 0.6660745872894994
# Change     = 0.0
# Generation = 71
# Fitness    = 0.6660745872894994
# Change     = 0.0
# Generation = 72
# Fitness    = 0.6660745872894994
# Change     = 0.0
# Generation = 73
# Fitness    = 0.6660745872894994
# Change     = 0.0
# Generation = 74
# Fitness    = 0.6660745872894994
# Change     = 0.0
# Generation = 75
# Fitness    = 0.6660745872894994
# Change     = 0.0
# Generation = 76
# Fitness    = 0.6669438002302911
# Change     = 0.0008692129407916749
# Generation = 77
# Fitness    = 0.6669438002302911
# Change     = 0.0
# Generation = 78
# Fitness    = 0.6695014856660909
# Change     = 0.002557685435799817
# Generation = 79
# Fitness    = 0.6695014856660909
# Change     = 0.0
# Generation = 80
# Fitness    = 0.6695014856660909
# Change     = 0.0
# Generation = 81
# Fitness    = 0.6720767472252621
# Change     = 0.0025752615591712047
# Generation = 82
# Fitness    = 0.6740687719163869
# Change     = 0.001992024691124805
# Generation = 83
# Fitness    = 0.6740687719163869
# Change     = 0.0
# Generation = 84
# Fitness    = 0.6740687719163869
# Change     = 0.0
# Generation = 85
# Fitness    = 0.6740687719163869
# Change     = 0.0
# Generation = 86
# Fitness    = 0.6740687719163869
# Change     = 0.0
# Generation = 87
# Fitness    = 0.6740687719163869
# Change     = 0.0
# Generation = 88
# Fitness    = 0.6770271796684573
# Change     = 0.0029584077520703467
# Generation = 89
# Fitness    = 0.6770271796684573
# Change     = 0.0
# Generation = 90
# Fitness    = 0.6770271796684573
# Change     = 0.0
# Generation = 91
# Fitness    = 0.6781665323765589
# Change     = 0.0011393527081016153
# Generation = 92
# Fitness    = 0.6781665323765589
# Change     = 0.0
# Generation = 93
# Fitness    = 0.6781665323765589
# Change     = 0.0
# Generation = 94
# Fitness    = 0.6781665323765589
# Change     = 0.0
# Generation = 95
# Fitness    = 0.6781665323765589
# Change     = 0.0
# Generation = 96
# Fitness    = 0.6781665323765589
# Change     = 0.0
# Generation = 97
# Fitness    = 0.6781665323765589
# Change     = 0.0
# Generation = 98
# Fitness    = 0.6793938457001584
# Change     = 0.0012273133235994882
# Generation = 99
# Fitness    = 0.6793938457001584
# Change     = 0.0
# Generation = 100
# Fitness    = 0.6793938457001584
# Change     = 0.0
# Generation = 101
# Fitness    = 0.6793938457001584
# Change     = 0.0
# Generation = 102
# Fitness    = 0.6793938457001584
# Change     = 0.0
# Generation = 103
# Fitness    = 0.679685276775496
# Change     = 0.00029143107533757817
# Generation = 104
# Fitness    = 0.679685276775496
# Change     = 0.0
# Generation = 105
# Fitness    = 0.679685276775496
# Change     = 0.0
# Generation = 106
# Fitness    = 0.679685276775496
# Change     = 0.0
# Generation = 107
# Fitness    = 0.679685276775496
# Change     = 0.0
# Generation = 108
# Fitness    = 0.679685276775496
# Change     = 0.0
# Generation = 109
# Fitness    = 0.679685276775496
# Change     = 0.0
# Generation = 110
# Fitness    = 0.679685276775496
# Change     = 0.0
# Generation = 111
# Fitness    = 0.679685276775496
# Change     = 0.0
# Generation = 112
# Fitness    = 0.679685276775496
# Change     = 0.0
# Generation = 113
# Fitness    = 0.679685276775496
# Change     = 0.0
# Generation = 114
# Fitness    = 0.679685276775496
# Change     = 0.0
# Generation = 115
# Fitness    = 0.6814388439554063
# Change     = 0.0017535671799103758
# Generation = 116
# Fitness    = 0.6814388439554063
# Change     = 0.0
# Generation = 117
# Fitness    = 0.6820058298345263
# Change     = 0.0005669858791199633
# Generation = 118
# Fitness    = 0.6822608337100317
# Change     = 0.0002550038755053663
# Generation = 119
# Fitness    = 0.6822608337100317
# Change     = 0.0
# Generation = 120
# Fitness    = 0.6822608337100317
# Change     = 0.0
# Generation = 121
# Fitness    = 0.682313971855223
# Change     = 5.313814519136706e-05
# Generation = 122
# Fitness    = 0.682313971855223
# Change     = 0.0
# Generation = 123
# Fitness    = 0.6829596451410032
# Change     = 0.000645673285780135
# Generation = 124
# Fitness    = 0.6829596451410032
# Change     = 0.0
# Generation = 125
# Fitness    = 0.6829596451410032
# Change     = 0.0
# Generation = 126
# Fitness    = 0.6848833731457474
# Change     = 0.001923728004744274
# Generation = 127
# Fitness    = 0.6848833731457474
# Change     = 0.0
# Generation = 128
# Fitness    = 0.6848833731457474
# Change     = 0.0
# Generation = 129
# Fitness    = 0.6848833731457474
# Change     = 0.0
# Generation = 130
# Fitness    = 0.6848833731457474
# Change     = 0.0
# Generation = 131
# Fitness    = 0.6848833731457474
# Change     = 0.0
# Generation = 132
# Fitness    = 0.6848833731457474
# Change     = 0.0
# Generation = 133
# Fitness    = 0.6848833731457474
# Change     = 0.0
# Generation = 134
# Fitness    = 0.6848833731457474
# Change     = 0.0
# Generation = 135
# Fitness    = 0.6848833731457474
# Change     = 0.0
# Generation = 136
# Fitness    = 0.6848833731457474
# Change     = 0.0
# Generation = 137
# Fitness    = 0.6848833731457474
# Change     = 0.0
# Generation = 138
# Fitness    = 0.6848833731457474
# Change     = 0.0
# Generation = 139
# Fitness    = 0.6848833731457474
# Change     = 0.0
# Generation = 140
# Fitness    = 0.68618538268926
# Change     = 0.0013020095435125612
# Generation = 141
# Fitness    = 0.68618538268926
# Change     = 0.0
# Generation = 142
# Fitness    = 0.68618538268926
# Change     = 0.0
# Generation = 143
# Fitness    = 0.68618538268926
# Change     = 0.0
# Generation = 144
# Fitness    = 0.68618538268926
# Change     = 0.0
# Generation = 145
# Fitness    = 0.68618538268926
# Change     = 0.0
# Generation = 146
# Fitness    = 0.68618538268926
# Change     = 0.0
# Generation = 147
# Fitness    = 0.68618538268926
# Change     = 0.0
# Generation = 148
# Fitness    = 0.68618538268926
# Change     = 0.0
# Generation = 149
# Fitness    = 0.68618538268926
# Change     = 0.0
# Generation = 150
# Fitness    = 0.68618538268926
# Change     = 0.0
# Generation = 151
# Fitness    = 0.68618538268926
# Change     = 0.0
# Generation = 152
# Fitness    = 0.6873940763276126
# Change     = 0.0012086936383526314
# Generation = 153
# Fitness    = 0.6873940763276126
# Change     = 0.0
# Generation = 154
# Fitness    = 0.6873940763276126
# Change     = 0.0
# Generation = 155
# Fitness    = 0.6873940763276126
# Change     = 0.0
# Generation = 156
# Fitness    = 0.6873940763276126
# Change     = 0.0
# Generation = 157
# Fitness    = 0.6873940763276126
# Change     = 0.0
# Generation = 158
# Fitness    = 0.6873940763276126
# Change     = 0.0
# Generation = 159
# Fitness    = 0.6873940763276126
# Change     = 0.0
# Generation = 160
# Fitness    = 0.6873940763276126
# Change     = 0.0
# Generation = 161
# Fitness    = 0.6873940763276126
# Change     = 0.0
# Generation = 162
# Fitness    = 0.6873940763276126
# Change     = 0.0
# Generation = 163
# Fitness    = 0.6873940763276126
# Change     = 0.0
# Generation = 164
# Fitness    = 0.6873940763276126
# Change     = 0.0
# Generation = 165
# Fitness    = 0.6873940763276126
# Change     = 0.0
# Generation = 166
# Fitness    = 0.6873940763276126
# Change     = 0.0
# Generation = 167
# Fitness    = 0.6873940763276126
# Change     = 0.0
# Generation = 168
# Fitness    = 0.6873940763276126
# Change     = 0.0
# Generation = 169
# Fitness    = 0.6875801132838578
# Change     = 0.00018603695624519467
# Generation = 170
# Fitness    = 0.6887797624093347
# Change     = 0.001199649125476876
# Generation = 171
# Fitness    = 0.6887797624093347
# Change     = 0.0
# Generation = 172
# Fitness    = 0.6887797624093347
# Change     = 0.0
# Generation = 173
# Fitness    = 0.6903263125549177
# Change     = 0.0015465501455830255
# Generation = 174
# Fitness    = 0.6903263125549177
# Change     = 0.0
# Generation = 175
# Fitness    = 0.6903263125549177
# Change     = 0.0
# Generation = 176
# Fitness    = 0.6903263125549177
# Change     = 0.0
# Generation = 177
# Fitness    = 0.6903263125549177
# Change     = 0.0
# Generation = 178
# Fitness    = 0.6903263125549177
# Change     = 0.0
# Generation = 179
# Fitness    = 0.6903263125549177
# Change     = 0.0
# Generation = 180
# Fitness    = 0.6903263125549177
# Change     = 0.0
# Generation = 181
# Fitness    = 0.6903263125549177
# Change     = 0.0
# Generation = 182
# Fitness    = 0.6903263125549177
# Change     = 0.0
# Generation = 183
# Fitness    = 0.6903263125549177
# Change     = 0.0
# Generation = 184
# Fitness    = 0.6903263125549177
# Change     = 0.0
# Generation = 185
# Fitness    = 0.6903263125549177
# Change     = 0.0
# Generation = 186
# Fitness    = 0.6903263125549177
# Change     = 0.0
# Generation = 187
# Fitness    = 0.6903263125549177
# Change     = 0.0
# Generation = 188
# Fitness    = 0.6903263125549177
# Change     = 0.0
# Generation = 189
# Fitness    = 0.6903263125549177
# Change     = 0.0
# Generation = 190
# Fitness    = 0.6905288556063286
# Change     = 0.00020254305141087503
# Generation = 191
# Fitness    = 0.6905288556063286
# Change     = 0.0
# Generation = 192
# Fitness    = 0.6917881089673573
# Change     = 0.0012592533610287227
# Generation = 193
# Fitness    = 0.6917881089673573
# Change     = 0.0
# Generation = 194
# Fitness    = 0.6917881089673573
# Change     = 0.0
# Generation = 195
# Fitness    = 0.6917881089673573
# Change     = 0.0
# Generation = 196
# Fitness    = 0.6917881089673573
# Change     = 0.0
# Generation = 197
# Fitness    = 0.6917881089673573
# Change     = 0.0
# Generation = 198
# Fitness    = 0.6917881089673573
# Change     = 0.0
# Generation = 199
# Fitness    = 0.6923025833908033
# Change     = 0.0005144744234459875
# Generation = 200
# Fitness    = 0.6923025833908033
# Change     = 0.0
# Generation = 201
